# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ecommerce_dataset (1).csv')
df.head()
# Out:
#    Order_ID  Order_Date  Customer_ID  Gender  Age           City  Product  \
# 0      1001  2024-01-01         2102    Male   23  Port Harcourt   Laptop
# 1      1002  2024-01-02         2435  Female   35         Ibadan  Blender
# 2      1003  2024-01-03         2860  Female   22         Ibadan  Blender
# 3      1004  2024-01-04         2270  Female   42           Kano   Laptop
# 4      1005  2024-01-05         2106  Female   19           Kano    Phone
#
#           Category   Price  Quantity Payment_Method  Revenue
# 0  Home Appliances  385589         1       Transfer   385589
# 1  Home Appliances  153892         4           Card   615568
# 2      Electronics  259717         4       Transfer  1038868
# 3      Electronics  314167         2           Card   628334
# 4  Home Appliances  169654         2       Transfer   339308

# %%
print("shape of dataset:", df.shape)
print("\ncolumns in dataset:")
print(df.columns)
# Out:
# shape of dataset: (500, 12)
#
# columns in dataset:
# Index(['Order_ID', 'Order_Date', 'Customer_ID', 'Gender', 'Age', 'City',
#        'Product', 'Category', 'Price', 'Quantity', 'Payment_Method',
#        'Revenue'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        500 non-null    int64
#  1   Order_Date      500 non-null    object
#  2   Customer_ID     500 non-null    int64
#  3   Gender          500 non-null    object
#  4   Age             500 non-null    int64
#  5   City            500 non-null    object
#  6   Product         500 non-null    object
#  7   Category        500 non-null    object
#  8   Price           500 non-null    int64
#  9   Quantity        500 non-null    int64
#  10  Payment_Method  500 non-null    object
#  11  Revenue         500 non-null    int64
# dtypes: int64(6), object(6)
# memory usage: 47.0+ KB

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_ID       0
# Gender            0
# Age               0
# City              0
# Product           0
# Category          0
# Price             0
# Quantity          0
# Payment_Method    0
# Revenue           0
# dtype: int64

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        500 non-null    int64
#  1   Order_Date      500 non-null    datetime64[ns]
#  2   Customer_ID     500 non-null    int64
#  3   Gender          500 non-null    object
#  4   Age             500 non-null    int64
#  5   City            500 non-null    object
#  6   Product         500 non-null    object
#  7   Category        500 non-null    object
#  8   Price           500 non-null    int64
#  9   Quantity        500 non-null    int64
#  10  Payment_Method  500 non-null    object
#  11  Revenue         500 non-null    int64
# dtypes: datetime64[ns](1), int64(6), object(5)
# memory usage: 47.0+ KB

# %%
df['Month'] = df['Order_Date'].dt.month
df[['Order_Date', 'Month']].head()
# Out:
#   Order_Date  Month
# 0 2024-01-01      1
# 1 2024-01-02      1
# 2 2024-01-03      1
# 3 2024-01-04      1
# 4 2024-01-05      1

# %%
def age_group(age):
    if age < 25:
        return 'Young'
    elif age < 45:
        return 'Adult'
    else:
        return 'Senior'
df['Age_Group'] = df['Age'].apply(age_group)
df[['Age', 'Age_Group']].head()
# Out:
#    Age Age_Group
# 0   23     Young
# 1   35     Adult
# 2   22     Young
# 3   42     Adult
# 4   19     Young

# %%
df['Revenue'] = pd.to_numeric(df['Revenue'], errors='coerce')
df['Revenue'].dtype
# Out:
# dtype('int64')

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_ID       0
# Gender            0
# Age               0
# City              0
# Product           0
# Category          0
# Price             0
# Quantity          0
# Payment_Method    0
# Revenue           0
# month             0
# Month             0
# Age_Group         0
# dtype: int64

# %%
df.head()
# Out:
#    Order_ID Order_Date  Customer_ID  Gender  Age           City  Product  \
# 0      1001 2024-01-01         2102    Male   23  Port Harcourt   Laptop
# 1      1002 2024-01-02         2435  Female   35         Ibadan  Blender
# 2      1003 2024-01-03         2860  Female   22         Ibadan  Blender
# 3      1004 2024-01-04         2270  Female   42           Kano   Laptop
# 4      1005 2024-01-05         2106  Female   19           Kano    Phone
#
#           Category   Price  Quantity Payment_Method  Revenue  month  Month  \
# 0  Home Appliances  385589         1       Transfer   385589      1      1
# 1  Home Appliances  153892         4           Card   615568      1      1
# 2      Electronics  259717         4       Transfer  1038868      1      1
# 3      Electronics  314167         2           Card   628334      1      1
# 4  Home Appliances  169654         2       Transfer   339308      1      1
#
#   Age_Group
# 0     Young
# 1     Adult
# 2     Young
# 3     Adult
# 4     Young

# %%
total_revenue = df['Revenue'].sum()
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 334811644

# %%
total_quantity = df['Quantity'].sum()
print("Total Quantity Sold:", total_quantity)
# Out:
# Total Quantity Sold: 1221

# %%
revenue_by_category = df.groupby('Category')['Revenue'].sum().sort_values(ascending=False)
revenue_by_category
# Out:
# Category
# Home Appliances    171354719
# Electronics        163456925
# Name: Revenue, dtype: int64

# %%
revenue_by_city =df.groupby('City')['Revenue'].sum().sort_values(ascending=False)
revenue_by_city
# Out:
# City
# Kano             75090540
# Port Harcourt    73663690
# Ibadan           63441485
# Abuja            62484807
# Lagos            60131122
# Name: Revenue, dtype: int64

# %%
monthly_sales =df.groupby('Month')['Revenue'].sum().sort_index()
monthly_sales
# Out:
# Month
# 1     45154848
# 2     41221160
# 3     38045285
# 4     41682186
# 5     30243973
# 6     22313943
# 7     17105310
# 8     18468783
# 9     18309097
# 10    16626182
# 11    18605298
# 12    27035579
# Name: Revenue, dtype: int64

# %%
top_5_products = df.groupby('Product')['Revenue'].sum().sort_values(ascending=False).head(5)
top_5_products
# Out:
# Product
# Phone      74734921
# Blender    71746523
# Fridge     67390132
# Laptop     64980917
# TV         55959151
# Name: Revenue, dtype: int64

# %%
gender_spending = df.groupby('Gender')['Revenue'].mean().sort_values(ascending=False)
gender_spending
# Out:
# Gender
# Female    670696.111111
# Male      668533.161290
# Name: Revenue, dtype: float64

# %%
payment_method = df['Payment_Method'].value_counts()
payment_method
# Out:
# Payment_Method
# Card        173
# Transfer    167
# Cash        160
# Name: count, dtype: int64

# %%
age_spending = df.groupby('Age')['Revenue'].mean()
age_spending.head(10)
# Out:
# Age
# 18    632024.687500
# 19    764910.000000
# 20    787264.000000
# 21    904694.538462
# 22    850005.411765
# 23    617046.250000
# 24    428427.142857
# 25    693591.133333
# 26    462311.888889
# 27    436438.533333
# Name: Revenue, dtype: float64

# %%
highest_product = df.groupby('Product')['Revenue'].sum().sort_values(ascending=False).head(1)
highest_product
# Out:
# Product
# Phone    74734921
# Name: Revenue, dtype: int64

# %%
top_city = df.groupby('City')['Revenue'].sum().sort_values(ascending=False).head(1)
top_city
# Out:
# City
# Kano    75090540
# Name: Revenue, dtype: int64

# %%
best_month = df.groupby('Month')['Revenue'].sum().sort_values(ascending=False).head(1)
best_month
# Out:
# Month
# 1    45154848
# Name: Revenue, dtype: int64

# %%
df.groupby('Category')['Revenue'].sum()
# Out:
# Category
# Electronics        163456925
# Home Appliances    171354719
# Name: Revenue, dtype: int64

# %%
df[df['Category'].isin(['Electronic','Home Appliance'])].groupby('Category')['Revenue'].sum()
# Out:
# Series([], Name: Revenue, dtype: int64)

# %%
df.groupby('Gender')['Revenue'].mean().sort_values(ascending=False)
# Out:
# Gender
# Female    670696.111111
# Male      668533.161290
# Name: Revenue, dtype: float64

# %%
df['Payment_Method'].value_counts().head(1)
# Out:
# Payment_Method
# Card    173
# Name: count, dtype: int64

# %%
df[['Age','Revenue']].corr()
# Out:
#               Age   Revenue
# Age      1.000000 -0.038184
# Revenue -0.038184  1.000000

# %%
df.groupby('Product')['Revenue'].sum().sort_values(ascending=False).head(10)
# Out:
# Product
# Phone      74734921
# Blender    71746523
# Fridge     67390132
# Laptop     64980917
# TV         55959151
# Name: Revenue, dtype: int64

# %%
df.groupby('Product')['Quantity'].sum().sort_values(ascending=False).head(10)
# Out:
# Product
# Phone      273
# Blender    270
# Laptop     240
# Fridge     237
# TV         201
# Name: Quantity, dtype: int64

# %%
revenue_by_category.plot(kind='bar')
plt.title('Revenue by Category')
plt.xlabel('Category')
plt.yticks('Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:1822, in Axis.convert_units(self, x)
#    1821 try:
# -> 1822     ret = self._converter.convert(x, self.units, self)
#    1823 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[47], line 4
#       2 plt.title('Revenue by Category')
#       3 plt.xlabel('Category')
# ----> 4 plt.yticks('Revenue')
#       5 plt.xticks(rotation=45)
#       6 plt.tight_layout()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2322, in yticks(ticks, labels, minor, **kwargs)
#    2319         raise TypeError("yticks(): Parameter 'labels' can't be set "
#    2320                         "without setting 'ticks'")
#    2321 else:
# -> 2322     locs = ax.set_yticks(ticks, minor=minor)
#    2324 labels_out: list[Text] = []
#    2325 if labels is None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:2229, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2224     first_key = next(iter(kwargs))
#    2225     raise ValueError(
#    2226         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#    2227         "other than 'minor' modify the text labels and can only be used if "
#    2228         "'labels' are passed as well.")
# -> 2229 result = self._set_tick_locations(ticks, minor=minor)
#    2230 if labels is not None:
#    2231     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:2169, in Axis._set_tick_locations(self, ticks, minor)
#    2165 def _set_tick_locations(self, ticks, *, minor=False):
#    2166     # see docstring of set_ticks
#    2167
#    2168     # XXX if the user changes units, the information will be lost here
# -> 2169     ticks = self.convert_units(ticks)
#    2170     locator = mticker.FixedLocator(ticks)  # validate ticks early.
#    2171     if len(ticks):
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:1824, in Axis.convert_units(self, x)
#    1822     ret = self._converter.convert(x, self.units, self)
#    1823 except Exception as e:
# -> 1824     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1825                                  f'units: {x!r}') from e
#    1826 return ret
#
# ConversionError: Failed to convert value(s) to axis units: 'Revenue'

# %%
revenue_by_city.plot(kind='bar')
plt.title('Revenue by City')
plt.xlabel('City')
plt.ylabel('Revenue')
plt.xticks(rotatio=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 5
#       3 plt.xlabel('City')
#       4 plt.ylabel('Revenue')
# ----> 5 plt.xticks(rotatio=45)
#       6 plt.tight_layout()
#       7 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2243, in xticks(ticks, labels, minor, **kwargs)
#    2241     labels_out = ax.get_xticklabels(minor=minor)
#    2242     for l in labels_out:
# -> 2243         l._internal_update(kwargs)
#    2244 else:
#    2245     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Text.set() got an unexpected keyword argument 'rotatio'

# %%
monthly_sales.plot(kind='line', marker='o')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.xticks(monthly_sales.index)
plt.tight_layout()
plt.show()

# %%
top_5_products.plot(kind='bar')
plt.title('Top 5 products by Revenue')
plt.xlabel('Product')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
gender_spending.plot(kind='bar')
plt.title('Average Spending by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Revenue')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
payment_method.plot(kind='bar')
plt.title('Most Used Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Age'], df['Revenue'])
plt.title('Age vs Revenue')
plt.xlabel('Age')
plt.ylabel('Revenue')
plt.tight_layout()
plt.show()

# %%
print("Total Revenue:",total_revenue)
print("Total Quantity Sold:",total_quantity)

print("\nRevenue by Category:")
print(revenue_by_category)

print("\nRevenue by City:")
print(revenue_by_city)

print("\nMonthly Sales Trend:")
print(monthly_sales)

print("\nTop 5 Products by Revenue:")
print(top_5_products)

print("\nAverage Spending by Gender:")
print(gender_spending)

print("\nMost Used Payment Method:")
print(payment_method)
# Out:
# Total Revenue: 334811644
# Total Quantity Sold: 1221
#
# Revenue by Category:
# Category
# Home Appliances    171354719
# Electronics        163456925
# Name: Revenue, dtype: int64
#
# Revenue by City:
# City
# Kano             75090540
# Port Harcourt    73663690
# Ibadan           63441485
# Abuja            62484807
# Lagos            60131122
# Name: Revenue, dtype: int64
#
# Monthly Sales Trend:
# Month
# 1     45154848
# 2     41221160
# 3     38045285
# 4     41682186
# 5     30243973
# 6     22313943
# 7     17105310
# 8     18468783
# 9     18309097
# 10    16626182
# 11    18605298
# 12    27035579
# Name: Revenue, dtype: int64
#
# Top 5 Products by Revenue:
# Product
# Phone      74734921
# Blender    71746523
# Fridge     67390132
# Laptop     64980917
# TV         55959151
# Name: Revenue, dtype: int64
#
# Average Spending by Gender:
# Gender
# Female    670696.111111
# Male      668533.161290
# Name: Revenue, dtype: float64
#
# Most Used Payment Method:
# Payment_Method
# Card        173
# Transfer    167
# Cash        160
# Name: count, dtype: int64

# %%
df. groupby('Gender')['Revenue'].mean()
# Out:
# Gender
# Female    670696.111111
# Male      668533.161290
# Name: Revenue, dtype: float64

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# Card        173
# Transfer    167
# Cash        160
# Name: count, dtype: int64

# %%
df.to_csv('cleaned_ecommerce_dataset.csv', index=False)
